# %% [markdown]
# #### [한글깨짐 오류수정]

# %%
# %pip install koreanize-matplotlib
# Out:
# Requirement already satisfied: koreanize-matplotlib in c:\users\kdp-27\anaconda3\envs\py39\lib\site-packages (0.1.1)
# Requirement already satisfied: matplotlib in c:\users\kdp-27\anaconda3\envs\py39\lib\site-packages (from koreanize-matplotlib) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kdp-27\anaconda3\envs\py39\lib\site-packages (from matplotlib->koreanize-matplotlib) (1.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\kdp-27\anaconda3\envs\py39\lib\site-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kdp-27\anaconda3\envs\py39\lib\site-packages (from matplotlib->koreanize-matplotlib) (4.37.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kdp-27\anaconda3\envs\py39\lib\site-packages (from matplotlib->koreanize-matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\kdp-27\anaconda3\envs\py39\lib\site-packages (from matplotlib->koreanize-matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kdp-27\anaconda3\envs\py39\lib\site-packages (from matplotlib->koreanize-matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\kdp-27\anaconda3\envs\py39\lib\site-packages (from matplotlib->koreanize-matplotlib) (8.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kdp-27\anaconda3\envs\py39\lib\site-packages (from matplotlib->koreanize-matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kdp-27\anaconda3\envs\py39\lib\site-packages (from matplotlib->koreanize-matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\kdp-27\anaconda3\envs\py39\lib\site-packages (from matplotlib->koreanize-matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\kdp-27\anaconda3\envs\py39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->koreanize-matplotlib) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\kdp-27\anaconda3\envs\py39\lib\site-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib
plt.plot([-1, 0, 1, 2])
plt.title('그래프제목', fontweight="bold")
plt.xlabel('간단한그래프')
plt.show()
