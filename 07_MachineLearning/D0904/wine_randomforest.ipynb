# %% [markdown]
# #### Ensemble - RandomForest & ExtraTree
# - 배깅 방식의 앙상블 ==> 중복 랜덤 샘플 + 동일 모델(DT)
#     * 대표 알고리즘 :  RandomForest L:
# - 페이스트 방식의 앙상블 ==> 랜덤 샘플 + 동일 모델(DT)
#     * 대표 알고리즘 : ExtraTreeC/R

# %% [markdown]
# [목표] 와인분류 => 0과 1, 2개 종류 분류
#
# [1] 모듈 로딩 및 데이터 준비

# %%
# 모듈로딩
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 데이터
DATA_FILE = '../data/wine.csv'

# CSV >> DataFrame
wineDF=pd.read_csv(DATA_FILE)

# %%
wineDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alcohol  6497 non-null   float64
#  1   sugar    6497 non-null   float64
#  2   pH       6497 non-null   float64
#  3   class    6497 non-null   float64
# dtypes: float64(4)
# memory usage: 203.2 KB

# %%
wineDF.head()
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0
# 2      9.8    2.3  3.26    0.0
# 3      9.8    1.9  3.16    0.0
# 4      9.4    1.9  3.51    0.0

# %%
# 타겟/라벨 분류 클래스 분포
wineDF['class'].value_counts()
# Out:
# class
# 1.0    4898
# 0.0    1599
# Name: count, dtype: int64

# %%
wineDF.describe()
# Out:
#            alcohol        sugar           pH        class
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean     10.491801     5.443235     3.218501     0.753886
# std       1.192712     4.757804     0.160787     0.430779
# min       8.000000     0.600000     2.720000     0.000000
# 25%       9.500000     1.800000     3.110000     1.000000
# 50%      10.300000     3.000000     3.210000     1.000000
# 75%      11.300000     8.100000     3.320000     1.000000
# max      14.900000    65.800000     4.010000     1.000000

# %% [markdown]
# [2] 학습 준비

# %%
# 학습용 & 테스트용 데이트셋 분할
from sklearn.model_selection import train_test_split

# %%
# 피쳐/독립변수와 타겟/라벨/종속변수 분리

featureDF=wineDF[wineDF.columns[:-1]]
targetSR=wineDF[wineDF.columns[-1]]

print(f'featureDF : {featureDF.shape} targetSR : {targetSR.shape}')
# Out:
# featureDF : (6497, 3) targetSR : (6497,)

# %%
# 학습용, 테스트용 데이터셋 분리
X_train, X_test, y_train, y_test = train_test_split( featureDF, targetSR,
                                                    test_size=0.2,
                                                    stratify=targetSR,
                                                    random_state=1)

# %%
print(f'X_train : {X_train.shape}, y_trian : {y_train.shape}')
print(f'X_tset : {X_test.shape}, y_test  {y_test.shape}')
# Out:
# X_train : (5197, 3), y_trian : (5197,)
# X_tset : (1300, 3), y_test  (1300,)

# %% [markdown]
# [3] 학습 진행

# %%
# 학습방법 : 지도학습 > 분류
# 알고리즘 : 앙상블 > 배깅 - RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# 인스턴스 생성 => 100개의 내부 DT 모델에서 사용할 데이터셋 생성
#                 Random_state 매개변수 설정으로 고정된 데이터셋 생성
#                 oob_score 매개변수 : 샘플 데이터셋 추출 후 남은 데이터셋 검증용으로 사용
lf_model = RandomForestClassifier(random_state=7,
                                  oob_score=True)

# 학습
lf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(oob_score=True, random_state=7)

# %%
#모델 파라미터
print(f'classes_ : {lf_model.classes_}')
print(f'n_classes_ : {lf_model.n_classes_}개')
print()
print(f'feature_names_in : {lf_model.feature_names_in_}')
print(f'n_festures_in_ : {lf_model.n_features_in_}개')
print(f'feature_importances_ : {lf_model.feature_importances_}')
# Out:
# classes_ : [0. 1.]
# n_classes_ : 2개
#
# feature_names_in : ['alcohol' 'sugar' 'pH']
# n_festures_in_ : 3개
# feature_importances_ : [0.23572103 0.49995154 0.26432743]

# %%
#모델 파라미터
print(f'lf_model.estimator_ : {lf_model.estimator_}')

for est in lf_model.estimators_: print(est)
# Out:
# lf_model.estimator_ : DecisionTreeClassifier()
# DecisionTreeClassifier(max_features='sqrt', random_state=327741615)
# DecisionTreeClassifier(max_features='sqrt', random_state=976413892)
# DecisionTreeClassifier(max_features='sqrt', random_state=1202242073)
# DecisionTreeClassifier(max_features='sqrt', random_state=1369975286)
# DecisionTreeClassifier(max_features='sqrt', random_state=1882953283)
# DecisionTreeClassifier(max_features='sqrt', random_state=2053951699)
# DecisionTreeClassifier(max_features='sqrt', random_state=959775639)
# DecisionTreeClassifier(max_features='sqrt', random_state=1956722279)
# DecisionTreeClassifier(max_features='sqrt', random_state=2052949340)
# DecisionTreeClassifier(max_features='sqrt', random_state=1322904761)
# DecisionTreeClassifier(max_features='sqrt', random_state=165338510)
# DecisionTreeClassifier(max_features='sqrt', random_state=1133316631)
# DecisionTreeClassifier(max_features='sqrt', random_state=4812360)
# DecisionTreeClassifier(max_features='sqrt', random_state=372560217)
# DecisionTreeClassifier(max_features='sqrt', random_state=309457262)
# DecisionTreeClassifier(max_features='sqrt', random_state=1801189930)
# DecisionTreeClassifier(max_features='sqrt', random_state=1152936666)
# DecisionTreeClassifier(max_features='sqrt', random_state=68334472)
# DecisionTreeClassifier(max_features='sqrt', random_state=2146978983)
# DecisionTreeClassifier(max_features='sqrt', random_state=119248870)
# DecisionTreeClassifier(max_features='sqrt', random_state=769786948)
# DecisionTreeClassifier(max_features='sqrt', random_state=1583990192)
# DecisionTreeClassifier(max_features='sqrt', random_state=1304549247)
# DecisionTreeClassifier(max_features='sqrt', random_state=1420943751)
# DecisionTreeClassifier(max_features='sqrt', random_state=1636129708)
# DecisionTreeClassifier(max_features='sqrt', random_state=1687674368)
# DecisionTreeClassifier(max_features='sqrt', random_state=283194443)
# DecisionTreeClassifier(max_features='sqrt', random_state=748743479)
# DecisionTreeClassifier(max_features='sqrt', random_state=1237575930)
# DecisionTreeClassifier(max_features='sqrt', random_state=740097030)
# DecisionTreeClassifier(max_features='sqrt', random_state=1759190803)
# DecisionTreeClassifier(max_features='sqrt', random_state=833359292)
# DecisionTreeClassifier(max_features='sqrt', random_state=916483116)
# DecisionTreeClassifier(max_features='sqrt', random_state=1485942463)
# DecisionTreeClassifier(max_features='sqrt', random_state=1941857605)
# DecisionTreeClassifier(max_features='sqrt', random_state=1844809528)
# DecisionTreeClassifier(max_features='sqrt', random_state=1852015768)
# DecisionTreeClassifier(max_features='sqrt', random_state=1127788727)
# DecisionTreeClassifier(max_features='sqrt', random_state=106941365)
# DecisionTreeClassifier(max_features='sqrt', random_state=1077017712)
# DecisionTreeClassifier(max_features='sqrt', random_state=431854331)
# DecisionTreeClassifier(max_features='sqrt', random_state=1094761661)
# DecisionTreeClassifier(max_features='sqrt', random_state=1933291456)
# DecisionTreeClassifier(max_features='sqrt', random_state=1508798754)
# DecisionTreeClassifier(max_features='sqrt', random_state=989143352)
# DecisionTreeClassifier(max_features='sqrt', random_state=747550921)
# DecisionTreeClassifier(max_features='sqrt', random_state=208262606)
# DecisionTreeClassifier(max_features='sqrt', random_state=1248819750)
# DecisionTreeClassifier(max_features='sqrt', random_state=1757192964)
# DecisionTreeClassifier(max_features='sqrt', random_state=1879603694)
# DecisionTreeClassifier(max_features='sqrt', random_state=571958409)
# DecisionTreeClassifier(max_features='sqrt', random_state=1927692119)
# DecisionTreeClassifier(max_features='sqrt', random_state=100556259)
# DecisionTreeClassifier(max_features='sqrt', random_state=1652057283)
# DecisionTreeClassifier(max_features='sqrt', random_state=1075502152)
# DecisionTreeClassifier(max_features='sqrt', random_state=1535344467)
# DecisionTreeClassifier(max_features='sqrt', random_state=725906352)
# DecisionTreeClassifier(max_features='sqrt', random_state=830456065)
# DecisionTreeClassifier(max_features='sqrt', random_state=2008983232)
# DecisionTreeClassifier(max_features='sqrt', random_state=431532432)
# DecisionTreeClassifier(max_features='sqrt', random_state=879820150)
# DecisionTreeClassifier(max_features='sqrt', random_state=2072909727)
# DecisionTreeClassifier(max_features='sqrt', random_state=2107823453)
# DecisionTreeClassifier(max_features='sqrt', random_state=488352684)
# DecisionTreeClassifier(max_features='sqrt', random_state=1599380060)
# DecisionTreeClassifier(max_features='sqrt', random_state=1938096892)
# DecisionTreeClassifier(max_features='sqrt', random_state=2050422343)
# DecisionTreeClassifier(max_features='sqrt', random_state=1497897239)
# DecisionTreeClassifier(max_features='sqrt', random_state=1571487242)
# DecisionTreeClassifier(max_features='sqrt', random_state=1187621609)
# DecisionTreeClassifier(max_features='sqrt', random_state=1451346723)
# DecisionTreeClassifier(max_features='sqrt', random_state=1917728192)
# DecisionTreeClassifier(max_features='sqrt', random_state=1153832253)
# DecisionTreeClassifier(max_features='sqrt', random_state=1966724487)
# DecisionTreeClassifier(max_features='sqrt', random_state=1348596887)
# DecisionTreeClassifier(max_features='sqrt', random_state=771276892)
# DecisionTreeClassifier(max_features='sqrt', random_state=311923447)
# DecisionTreeClassifier(max_features='sqrt', random_state=612959456)
# DecisionTreeClassifier(max_features='sqrt', random_state=1185621653)
# DecisionTreeClassifier(max_features='sqrt', random_state=358664548)
# DecisionTreeClassifier(max_features='sqrt', random_state=1944945571)
# DecisionTreeClassifier(max_features='sqrt', random_state=202873313)
# DecisionTreeClassifier(max_features='sqrt', random_state=1516030531)
# DecisionTreeClassifier(max_features='sqrt', random_state=1332338555)
# DecisionTreeClassifier(max_features='sqrt', random_state=676025563)
# DecisionTreeClassifier(max_features='sqrt', random_state=1214271969)
# DecisionTreeClassifier(max_features='sqrt', random_state=1590645779)
# DecisionTreeClassifier(max_features='sqrt', random_state=1808153499)
# DecisionTreeClassifier(max_features='sqrt', random_state=1971789316)
# DecisionTreeClassifier(max_features='sqrt', random_state=1861190419)
# DecisionTreeClassifier(max_features='sqrt', random_state=941989921)
# DecisionTreeClassifier(max_features='sqrt', random_state=1798548603)
# DecisionTreeClassifier(max_features='sqrt', random_state=1773786398)
# DecisionTreeClassifier(max_features='sqrt', random_state=2088312505)
# DecisionTreeClassifier(max_features='sqrt', random_state=1745574629)
# DecisionTreeClassifier(max_features='sqrt', random_state=1260873545)
# DecisionTreeClassifier(max_features='sqrt', random_state=775033821)
# DecisionTreeClassifier(max_features='sqrt', random_state=1474484177)
# DecisionTreeClassifier(max_features='sqrt', random_state=1035597695)
# DecisionTreeClassifier(max_features='sqrt', random_state=1289946527)

# %% [markdown]
# [4] 성능평가

# %%
train_score=lf_model.score(X_train,y_train)
test_score=lf_model.score(X_test,y_test)

# %%
print(f'train_score : {train_score} , test_score : {test_score}')
# Out:
# train_score : 0.9973061381566288 , test_score : 0.9

# %%
print(f'oob_score_ : {lf_model.oob_score_}')
# Out:
# oob_score_ : 0.89532422551472

# %% [markdown]
# [5] 튜닝
# - RandomizedSearchCV 하이퍼파라미터 최적화 클래스
#     * 범위가 넓은 하이퍼파라미터 설정에 좋음
#     * 지정된 범위에서 지정된 횟수 만큼 하이퍼파라미터를 추출하여 조합 진행

# %%
# 모듈 로딩
from sklearn.model_selection import RandomizedSearchCV

# %%
# RandomForestCalssifier 하이퍼파라미터 설정
params={'max_depth':range(2,16),
        'min_samples_leaf': range(5,16),
        'criterion':['gini','entropy','log_loss']}

# %%
rf_model=RandomForestClassifier(n_estimators=300,random_state=7)

# %%
searchCV = RandomizedSearchCV(rf_model,
                              param_distributions=params,
                              verbose=4,
                              n_iter=50)

# %%
searchCV.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.869 total time=   0.6s
# [CV 2/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.838 total time=   0.6s
# [CV 3/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.877 total time=   0.6s
# [CV 4/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.882 total time=   0.6s
# [CV 5/5] END criterion=log_loss, max_depth=9, min_samples_leaf=15;, score=0.867 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=3, min_samples_leaf=15;, score=0.815 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=3, min_samples_leaf=15;, score=0.820 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=3, min_samples_leaf=15;, score=0.819 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=3, min_samples_leaf=15;, score=0.832 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=3, min_samples_leaf=15;, score=0.828 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=8, min_samples_leaf=15;, score=0.867 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=8, min_samples_leaf=15;, score=0.837 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=8, min_samples_leaf=15;, score=0.876 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=8, min_samples_leaf=15;, score=0.884 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=8, min_samples_leaf=15;, score=0.863 total time=   0.6s
# [CV 1/5] END criterion=log_loss, max_depth=3, min_samples_leaf=12;, score=0.799 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=3, min_samples_leaf=12;, score=0.808 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=3, min_samples_leaf=12;, score=0.809 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=3, min_samples_leaf=12;, score=0.824 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=3, min_samples_leaf=12;, score=0.825 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=7, min_samples_leaf=12;, score=0.869 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=7, min_samples_leaf=12;, score=0.835 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=7, min_samples_leaf=12;, score=0.880 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=7, min_samples_leaf=12;, score=0.879 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=7, min_samples_leaf=12;, score=0.862 total time=   0.5s
# [CV 1/5] END criterion=log_loss, max_depth=7, min_samples_leaf=8;, score=0.868 total time=   0.6s
# [CV 2/5] END criterion=log_loss, max_depth=7, min_samples_leaf=8;, score=0.835 total time=   0.6s
# [CV 3/5] END criterion=log_loss, max_depth=7, min_samples_leaf=8;, score=0.881 total time=   0.6s
# [CV 4/5] END criterion=log_loss, max_depth=7, min_samples_leaf=8;, score=0.880 total time=   0.6s
# [CV 5/5] END criterion=log_loss, max_depth=7, min_samples_leaf=8;, score=0.861 total time=   0.6s
# [CV 1/5] END criterion=log_loss, max_depth=8, min_samples_leaf=12;, score=0.870 total time=   0.6s
# [CV 2/5] END criterion=log_loss, max_depth=8, min_samples_leaf=12;, score=0.836 total time=   0.6s
# [CV 3/5] END criterion=log_loss, max_depth=8, min_samples_leaf=12;, score=0.882 total time=   0.6s
# [CV 4/5] END criterion=log_loss, max_depth=8, min_samples_leaf=12;, score=0.881 total time=   0.6s
# [CV 5/5] END criterion=log_loss, max_depth=8, min_samples_leaf=12;, score=0.869 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=14;, score=0.872 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=14;, score=0.832 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=14;, score=0.879 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=14;, score=0.883 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=14;, score=0.872 total time=   0.6s
# [CV 1/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.863 total time=   0.5s
# [CV 2/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.833 total time=   0.5s
# [CV 3/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.872 total time=   0.5s
# [CV 4/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.878 total time=   0.5s
# [CV 5/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.858 total time=   0.5s
# [CV 1/5] END criterion=log_loss, max_depth=7, min_samples_leaf=10;, score=0.868 total time=   0.6s
# [CV 2/5] END criterion=log_loss, max_depth=7, min_samples_leaf=10;, score=0.838 total time=   0.6s
# [CV 3/5] END criterion=log_loss, max_depth=7, min_samples_leaf=10;, score=0.882 total time=   0.6s
# [CV 4/5] END criterion=log_loss, max_depth=7, min_samples_leaf=10;, score=0.876 total time=   0.6s
# [CV 5/5] END criterion=log_loss, max_depth=7, min_samples_leaf=10;, score=0.863 total time=   0.6s
# [CV 1/5] END criterion=log_loss, max_depth=7, min_samples_leaf=11;, score=0.862 total time=   0.6s
# [CV 2/5] END criterion=log_loss, max_depth=7, min_samples_leaf=11;, score=0.836 total time=   0.6s
# [CV 3/5] END criterion=log_loss, max_depth=7, min_samples_leaf=11;, score=0.878 total time=   0.6s
# [CV 4/5] END criterion=log_loss, max_depth=7, min_samples_leaf=11;, score=0.879 total time=   0.6s
# [CV 5/5] END criterion=log_loss, max_depth=7, min_samples_leaf=11;, score=0.863 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.891 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.848 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.880 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.890 total time=   0.9s
# [CV 5/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.879 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=3, min_samples_leaf=10;, score=0.800 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=3, min_samples_leaf=10;, score=0.802 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=3, min_samples_leaf=10;, score=0.809 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=3, min_samples_leaf=10;, score=0.824 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=3, min_samples_leaf=10;, score=0.823 total time=   0.4s
# [CV 1/5] END criterion=log_loss, max_depth=4, min_samples_leaf=10;, score=0.828 total time=   0.4s
# [CV 2/5] END criterion=log_loss, max_depth=4, min_samples_leaf=10;, score=0.839 total time=   0.4s
# [CV 3/5] END criterion=log_loss, max_depth=4, min_samples_leaf=10;, score=0.854 total time=   0.4s
# [CV 4/5] END criterion=log_loss, max_depth=4, min_samples_leaf=10;, score=0.863 total time=   0.4s
# [CV 5/5] END criterion=log_loss, max_depth=4, min_samples_leaf=10;, score=0.847 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=7, min_samples_leaf=8;, score=0.868 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=7, min_samples_leaf=8;, score=0.835 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=7, min_samples_leaf=8;, score=0.881 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=7, min_samples_leaf=8;, score=0.880 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=7, min_samples_leaf=8;, score=0.861 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=4, min_samples_leaf=13;, score=0.829 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=4, min_samples_leaf=13;, score=0.839 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=4, min_samples_leaf=13;, score=0.855 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=4, min_samples_leaf=13;, score=0.863 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=4, min_samples_leaf=13;, score=0.848 total time=   0.4s
# [CV 1/5] END criterion=log_loss, max_depth=2, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=2, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=2, min_samples_leaf=6;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=2, min_samples_leaf=6;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=log_loss, max_depth=2, min_samples_leaf=6;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=8, min_samples_leaf=9;, score=0.870 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=8, min_samples_leaf=9;, score=0.836 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=8, min_samples_leaf=9;, score=0.880 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=8, min_samples_leaf=9;, score=0.883 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=8, min_samples_leaf=9;, score=0.869 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=14, min_samples_leaf=14;, score=0.874 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=14, min_samples_leaf=14;, score=0.840 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=14, min_samples_leaf=14;, score=0.878 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=14, min_samples_leaf=14;, score=0.885 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=14, min_samples_leaf=14;, score=0.873 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=10;, score=0.871 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=10;, score=0.839 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=10;, score=0.871 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=10;, score=0.879 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=10;, score=0.874 total time=   0.7s
# [CV 1/5] END criterion=log_loss, max_depth=7, min_samples_leaf=15;, score=0.860 total time=   0.6s
# [CV 2/5] END criterion=log_loss, max_depth=7, min_samples_leaf=15;, score=0.835 total time=   0.7s
# [CV 3/5] END criterion=log_loss, max_depth=7, min_samples_leaf=15;, score=0.879 total time=   0.7s
# [CV 4/5] END criterion=log_loss, max_depth=7, min_samples_leaf=15;, score=0.879 total time=   0.6s
# [CV 5/5] END criterion=log_loss, max_depth=7, min_samples_leaf=15;, score=0.863 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=2, min_samples_leaf=5;, score=0.767 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=2, min_samples_leaf=5;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=11, min_samples_leaf=6;, score=0.877 total time=   0.9s
# [CV 2/5] END criterion=entropy, max_depth=11, min_samples_leaf=6;, score=0.843 total time=   0.9s
# [CV 3/5] END criterion=entropy, max_depth=11, min_samples_leaf=6;, score=0.881 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=11, min_samples_leaf=6;, score=0.885 total time=   0.9s
# [CV 5/5] END criterion=entropy, max_depth=11, min_samples_leaf=6;, score=0.879 total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=14, min_samples_leaf=15;, score=0.873 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=14, min_samples_leaf=15;, score=0.835 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=14, min_samples_leaf=15;, score=0.878 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=14, min_samples_leaf=15;, score=0.883 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=14, min_samples_leaf=15;, score=0.867 total time=   0.9s
# [CV 1/5] END criterion=log_loss, max_depth=6, min_samples_leaf=8;, score=0.857 total time=   0.6s
# [CV 2/5] END criterion=log_loss, max_depth=6, min_samples_leaf=8;, score=0.832 total time=   0.6s
# [CV 3/5] END criterion=log_loss, max_depth=6, min_samples_leaf=8;, score=0.870 total time=   0.7s
# [CV 4/5] END criterion=log_loss, max_depth=6, min_samples_leaf=8;, score=0.874 total time=   0.6s
# [CV 5/5] END criterion=log_loss, max_depth=6, min_samples_leaf=8;, score=0.860 total time=   0.7s
# [CV 1/5] END criterion=log_loss, max_depth=13, min_samples_leaf=6;, score=0.882 total time=   1.1s
# [CV 2/5] END criterion=log_loss, max_depth=13, min_samples_leaf=6;, score=0.844 total time=   1.0s
# [CV 3/5] END criterion=log_loss, max_depth=13, min_samples_leaf=6;, score=0.885 total time=   1.1s
# [CV 4/5] END criterion=log_loss, max_depth=13, min_samples_leaf=6;, score=0.887 total time=   1.0s
# [CV 5/5] END criterion=log_loss, max_depth=13, min_samples_leaf=6;, score=0.877 total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=6, min_samples_leaf=15;, score=0.863 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=6, min_samples_leaf=15;, score=0.834 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=6, min_samples_leaf=15;, score=0.872 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=6, min_samples_leaf=15;, score=0.876 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=6, min_samples_leaf=15;, score=0.858 total time=   0.5s
# [CV 1/5] END criterion=log_loss, max_depth=14, min_samples_leaf=6;, score=0.884 total time=   0.8s
# [CV 2/5] END criterion=log_loss, max_depth=14, min_samples_leaf=6;, score=0.847 total time=   0.8s
# [CV 3/5] END criterion=log_loss, max_depth=14, min_samples_leaf=6;, score=0.883 total time=   0.8s
# [CV 4/5] END criterion=log_loss, max_depth=14, min_samples_leaf=6;, score=0.887 total time=   0.8s
# [CV 5/5] END criterion=log_loss, max_depth=14, min_samples_leaf=6;, score=0.879 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=4, min_samples_leaf=14;, score=0.829 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=4, min_samples_leaf=14;, score=0.840 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=4, min_samples_leaf=14;, score=0.855 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=4, min_samples_leaf=14;, score=0.863 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=4, min_samples_leaf=14;, score=0.848 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=7, min_samples_leaf=6;, score=0.872 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=7, min_samples_leaf=6;, score=0.838 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=7, min_samples_leaf=6;, score=0.881 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=7, min_samples_leaf=6;, score=0.876 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=7, min_samples_leaf=6;, score=0.863 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=2, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=2, min_samples_leaf=11;, score=0.767 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=2, min_samples_leaf=11;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=2, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=2, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=4, min_samples_leaf=15;, score=0.828 total time=   0.4s
# [CV 2/5] END criterion=log_loss, max_depth=4, min_samples_leaf=15;, score=0.840 total time=   0.4s
# [CV 3/5] END criterion=log_loss, max_depth=4, min_samples_leaf=15;, score=0.855 total time=   0.4s
# [CV 4/5] END criterion=log_loss, max_depth=4, min_samples_leaf=15;, score=0.862 total time=   0.4s
# [CV 5/5] END criterion=log_loss, max_depth=4, min_samples_leaf=15;, score=0.848 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=14;, score=0.871 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=14;, score=0.838 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=14;, score=0.877 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=14;, score=0.885 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=14;, score=0.868 total time=   0.7s
# [CV 1/5] END criterion=log_loss, max_depth=5, min_samples_leaf=11;, score=0.855 total time=   0.5s
# [CV 2/5] END criterion=log_loss, max_depth=5, min_samples_leaf=11;, score=0.834 total time=   0.5s
# [CV 3/5] END criterion=log_loss, max_depth=5, min_samples_leaf=11;, score=0.860 total time=   0.5s
# [CV 4/5] END criterion=log_loss, max_depth=5, min_samples_leaf=11;, score=0.875 total time=   0.5s
# [CV 5/5] END criterion=log_loss, max_depth=5, min_samples_leaf=11;, score=0.856 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=5, min_samples_leaf=9;, score=0.852 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=5, min_samples_leaf=9;, score=0.836 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=5, min_samples_leaf=9;, score=0.861 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=5, min_samples_leaf=9;, score=0.875 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=5, min_samples_leaf=9;, score=0.856 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.815 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.819 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.811 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.833 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.828 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=7;, score=0.872 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=7;, score=0.845 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=7;, score=0.878 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=7;, score=0.885 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=7;, score=0.872 total time=   0.7s
# [CV 1/5] END criterion=log_loss, max_depth=5, min_samples_leaf=6;, score=0.855 total time=   0.5s
# [CV 2/5] END criterion=log_loss, max_depth=5, min_samples_leaf=6;, score=0.837 total time=   0.5s
# [CV 3/5] END criterion=log_loss, max_depth=5, min_samples_leaf=6;, score=0.860 total time=   0.5s
# [CV 4/5] END criterion=log_loss, max_depth=5, min_samples_leaf=6;, score=0.876 total time=   0.5s
# [CV 5/5] END criterion=log_loss, max_depth=5, min_samples_leaf=6;, score=0.857 total time=   0.5s
# [CV 1/5] END criterion=log_loss, max_depth=14, min_samples_leaf=7;, score=0.885 total time=   0.8s
# [CV 2/5] END criterion=log_loss, max_depth=14, min_samples_leaf=7;, score=0.845 total time=   0.8s
# [CV 3/5] END criterion=log_loss, max_depth=14, min_samples_leaf=7;, score=0.883 total time=   0.8s
# [CV 4/5] END criterion=log_loss, max_depth=14, min_samples_leaf=7;, score=0.887 total time=   0.8s
# [CV 5/5] END criterion=log_loss, max_depth=14, min_samples_leaf=7;, score=0.877 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=15;, score=0.869 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=15;, score=0.838 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=15;, score=0.877 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=15;, score=0.882 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=15;, score=0.867 total time=   0.6s
# [CV 1/5] END criterion=log_loss, max_depth=2, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=2, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=2, min_samples_leaf=8;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=2, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=2, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=9, min_samples_leaf=7;, score=0.877 total time=   0.7s
# [CV 2/5] END criterion=log_loss, max_depth=9, min_samples_leaf=7;, score=0.843 total time=   0.7s
# [CV 3/5] END criterion=log_loss, max_depth=9, min_samples_leaf=7;, score=0.876 total time=   0.7s
# [CV 4/5] END criterion=log_loss, max_depth=9, min_samples_leaf=7;, score=0.884 total time=   0.7s
# [CV 5/5] END criterion=log_loss, max_depth=9, min_samples_leaf=7;, score=0.873 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=11, min_samples_leaf=8;, score=0.871 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=11, min_samples_leaf=8;, score=0.842 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=11, min_samples_leaf=8;, score=0.875 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=11, min_samples_leaf=8;, score=0.886 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=11, min_samples_leaf=8;, score=0.874 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.859 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.835 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.867 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.878 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.850 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=15, min_samples_leaf=8;, score=0.882 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=15, min_samples_leaf=8;, score=0.838 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=15, min_samples_leaf=8;, score=0.879 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=15, min_samples_leaf=8;, score=0.886 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=15, min_samples_leaf=8;, score=0.874 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=13, min_samples_leaf=8;, score=0.882 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=13, min_samples_leaf=8;, score=0.838 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=13, min_samples_leaf=8;, score=0.876 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=13, min_samples_leaf=8;, score=0.886 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=13, min_samples_leaf=8;, score=0.875 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=2, min_samples_leaf=5;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=6, min_samples_leaf=5;, score=0.863 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=6, min_samples_leaf=5;, score=0.836 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=6, min_samples_leaf=5;, score=0.874 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=6, min_samples_leaf=5;, score=0.880 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=6, min_samples_leaf=5;, score=0.860 total time=   0.5s
# [CV 1/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.881 total time=   0.8s
# [CV 2/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.844 total time=   0.8s
# [CV 3/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.879 total time=   0.8s
# [CV 4/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.887 total time=   0.8s
# [CV 5/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.876 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=15, min_samples_leaf=12;, score=0.876 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=15, min_samples_leaf=12;, score=0.837 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=15, min_samples_leaf=12;, score=0.880 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=15, min_samples_leaf=12;, score=0.885 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=15, min_samples_leaf=12;, score=0.872 total time=   0.7s
# RandomizedSearchCV(estimator=RandomForestClassifier(n_estimators=300,
#                                                     random_state=7),
#                    n_iter=50,
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': range(2, 16),
#                                         'min_samples_leaf': range(5, 16)},
#                    verbose=4)

# %%
# 모델 파라미터
print(f'[searchCV.best_score_] {searchCV.best_score_}')
print(f'[searchCV.best_params_] {searchCV.best_params_}')
print(f'[searchCV.best_estimator_] {searchCV.best_estimator_}')

cv_resultDF=pd.DataFrame(searchCV.cv_results_)
cv_resultDF
# Out:
# [searchCV.best_score_] 0.8776247501295625
# [searchCV.best_params_] {'min_samples_leaf': 5, 'max_depth': 15, 'criterion': 'entropy'}
# [searchCV.best_estimator_] RandomForestClassifier(criterion='entropy', max_depth=15, min_samples_leaf=5,
#                        n_estimators=300, random_state=7)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.677670      0.017834         0.038502        0.000487
# 1        0.410321      0.001613         0.026325        0.000509
# 2        0.633818      0.003583         0.036702        0.000417
# 3        0.417327      0.001629         0.026142        0.000515
# 4        0.597035      0.002865         0.036385        0.000507
# 5        0.631540      0.009014         0.035877        0.001093
# 6        0.651489      0.004268         0.037345        0.000455
# 7        0.658886      0.007144         0.039775        0.001310
# 8        0.576212      0.000820         0.034165        0.000752
# 9        0.635930      0.006070         0.036566        0.000804
# 10       0.640749      0.004706         0.038212        0.001089
# 11       0.903977      0.026040         0.044357        0.000885
# 12       0.439774      0.003057         0.026897        0.000632
# 13       0.487498      0.005482         0.029300        0.001198
# 14       0.691053      0.018308         0.039010        0.001424
# 15       0.530135      0.042038         0.032318        0.002367
# 16       0.415770      0.008904         0.026867        0.001115
# 17       0.718400      0.009832         0.041265        0.002063
# 18       0.731155      0.004266         0.041707        0.001725
# 19       0.731470      0.011678         0.041836        0.000888
# 20       0.725041      0.039460         0.042011        0.002903
# 21       0.443164      0.022210         0.029502        0.003888
# 22       0.974288      0.024640         0.052939        0.008618
# 23       0.869092      0.033777         0.047049        0.008002
# 24       0.701858      0.008773         0.045738        0.005319
# 25       1.086622      0.039001         0.049260        0.004559
# 26       0.589166      0.006139         0.035839        0.000593
# 27       0.844884      0.007231         0.044393        0.001050
# 28       0.489735      0.003283         0.030697        0.000399
# 29       0.644159      0.008152         0.038862        0.001120
# 30       0.392346      0.003833         0.025608        0.001039
# 31       0.489859      0.006279         0.030497        0.000495
# 32       0.701342      0.007729         0.041447        0.000772
# 33       0.548777      0.010248         0.032721        0.000963
# 34       0.543782      0.009648         0.033961        0.001142
# 35       0.437046      0.004773         0.027500        0.000794
# 36       0.786166      0.006782         0.043876        0.001048
# 37       0.550066      0.005798         0.033974        0.000792
# 38       0.832106      0.004939         0.044192        0.000777
# 39       0.698664      0.019270         0.041078        0.000760
# 40       0.403837      0.004117         0.025696        0.000636
# 41       0.758008      0.006833         0.042465        0.000480
# 42       0.809417      0.023548         0.043863        0.000907
# 43       0.542822      0.007381         0.034624        0.000750
# 44       0.782197      0.009366         0.043871        0.000873
# 45       0.783439      0.005777         0.044665        0.000406
# 46       0.404752      0.002925         0.025711        0.000403
# 47       0.605845      0.003239         0.036876        0.000632
# 48       0.829146      0.004994         0.043454        0.001017
# 49       0.725168      0.008448         0.043071        0.000742
#
#    param_min_samples_leaf param_max_depth param_criterion  \
# 0                      15               9        log_loss
# 1                      15               3            gini
# 2                      15               8         entropy
# 3                      12               3        log_loss
# 4                      12               7            gini
# 5                       8               7        log_loss
# 6                      12               8        log_loss
# 7                      14              10            gini
# 8                      13               6        log_loss
# 9                      10               7        log_loss
# 10                     11               7        log_loss
# 11                      5              15         entropy
# 12                     10               3         entropy
# 13                     10               4        log_loss
# 14                      8               7         entropy
# 15                     13               4         entropy
# 16                      6               2        log_loss
# 17                      9               8         entropy
# 18                     14              14         entropy
# 19                     10               9         entropy
# 20                     15               7        log_loss
# 21                      5               2            gini
# 22                      6              11         entropy
# 23                     15              14         entropy
# 24                      8               6        log_loss
# 25                      6              13        log_loss
# 26                     15               6         entropy
# 27                      6              14        log_loss
# 28                     14               4         entropy
# 29                      6               7            gini
# 30                     11               2            gini
# 31                     15               4        log_loss
# 32                     14               9         entropy
# 33                     11               5        log_loss
# 34                      9               5         entropy
# 35                      5               3            gini
# 36                      7              10         entropy
# 37                      6               5        log_loss
# 38                      7              14        log_loss
# 39                     15               9         entropy
# 40                      8               2        log_loss
# 41                      7               9        log_loss
# 42                      8              11         entropy
# 43                     10               5            gini
# 44                      8              15            gini
# 45                      8              13            gini
# 46                      5               2         entropy
# 47                      5               6            gini
# 48                      7              12        log_loss
# 49                     12              15            gini
#
#                                                params  split0_test_score  \
# 0   {'min_samples_leaf': 15, 'max_depth': 9, 'crit...           0.869231
# 1   {'min_samples_leaf': 15, 'max_depth': 3, 'crit...           0.815385
# 2   {'min_samples_leaf': 15, 'max_depth': 8, 'crit...           0.867308
# 3   {'min_samples_leaf': 12, 'max_depth': 3, 'crit...           0.799038
# 4   {'min_samples_leaf': 12, 'max_depth': 7, 'crit...           0.869231
# 5   {'min_samples_leaf': 8, 'max_depth': 7, 'crite...           0.868269
# 6   {'min_samples_leaf': 12, 'max_depth': 8, 'crit...           0.870192
# 7   {'min_samples_leaf': 14, 'max_depth': 10, 'cri...           0.872115
# 8   {'min_samples_leaf': 13, 'max_depth': 6, 'crit...           0.862500
# 9   {'min_samples_leaf': 10, 'max_depth': 7, 'crit...           0.868269
# 10  {'min_samples_leaf': 11, 'max_depth': 7, 'crit...           0.861538
# 11  {'min_samples_leaf': 5, 'max_depth': 15, 'crit...           0.891346
# 12  {'min_samples_leaf': 10, 'max_depth': 3, 'crit...           0.800000
# 13  {'min_samples_leaf': 10, 'max_depth': 4, 'crit...           0.827885
# 14  {'min_samples_leaf': 8, 'max_depth': 7, 'crite...           0.868269
# 15  {'min_samples_leaf': 13, 'max_depth': 4, 'crit...           0.828846
# 16  {'min_samples_leaf': 6, 'max_depth': 2, 'crite...           0.753846
# 17  {'min_samples_leaf': 9, 'max_depth': 8, 'crite...           0.870192
# 18  {'min_samples_leaf': 14, 'max_depth': 14, 'cri...           0.874038
# 19  {'min_samples_leaf': 10, 'max_depth': 9, 'crit...           0.871154
# 20  {'min_samples_leaf': 15, 'max_depth': 7, 'crit...           0.859615
# 21  {'min_samples_leaf': 5, 'max_depth': 2, 'crite...           0.753846
# 22  {'min_samples_leaf': 6, 'max_depth': 11, 'crit...           0.876923
# 23  {'min_samples_leaf': 15, 'max_depth': 14, 'cri...           0.873077
# 24  {'min_samples_leaf': 8, 'max_depth': 6, 'crite...           0.856731
# 25  {'min_samples_leaf': 6, 'max_depth': 13, 'crit...           0.881731
# 26  {'min_samples_leaf': 15, 'max_depth': 6, 'crit...           0.863462
# 27  {'min_samples_leaf': 6, 'max_depth': 14, 'crit...           0.883654
# 28  {'min_samples_leaf': 14, 'max_depth': 4, 'crit...           0.828846
# 29  {'min_samples_leaf': 6, 'max_depth': 7, 'crite...           0.872115
# 30  {'min_samples_leaf': 11, 'max_depth': 2, 'crit...           0.753846
# 31  {'min_samples_leaf': 15, 'max_depth': 4, 'crit...           0.827885
# 32  {'min_samples_leaf': 14, 'max_depth': 9, 'crit...           0.871154
# 33  {'min_samples_leaf': 11, 'max_depth': 5, 'crit...           0.854808
# 34  {'min_samples_leaf': 9, 'max_depth': 5, 'crite...           0.851923
# 35  {'min_samples_leaf': 5, 'max_depth': 3, 'crite...           0.815385
# 36  {'min_samples_leaf': 7, 'max_depth': 10, 'crit...           0.872115
# 37  {'min_samples_leaf': 6, 'max_depth': 5, 'crite...           0.854808
# 38  {'min_samples_leaf': 7, 'max_depth': 14, 'crit...           0.884615
# 39  {'min_samples_leaf': 15, 'max_depth': 9, 'crit...           0.869231
# 40  {'min_samples_leaf': 8, 'max_depth': 2, 'crite...           0.753846
# 41  {'min_samples_leaf': 7, 'max_depth': 9, 'crite...           0.876923
# 42  {'min_samples_leaf': 8, 'max_depth': 11, 'crit...           0.871154
# 43  {'min_samples_leaf': 10, 'max_depth': 5, 'crit...           0.858654
# 44  {'min_samples_leaf': 8, 'max_depth': 15, 'crit...           0.881731
# 45  {'min_samples_leaf': 8, 'max_depth': 13, 'crit...           0.881731
# 46  {'min_samples_leaf': 5, 'max_depth': 2, 'crite...           0.753846
# 47  {'min_samples_leaf': 5, 'max_depth': 6, 'crite...           0.863462
# 48  {'min_samples_leaf': 7, 'max_depth': 12, 'crit...           0.880769
# 49  {'min_samples_leaf': 12, 'max_depth': 15, 'cri...           0.875962
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.838462           0.876805           0.881617
# 1            0.820192           0.819057           0.831569
# 2            0.836538           0.875842           0.883542
# 3            0.807692           0.809432           0.823869
# 4            0.834615           0.879692           0.878730
# 5            0.834615           0.880654           0.879692
# 6            0.835577           0.881617           0.880654
# 7            0.831731           0.878730           0.882579
# 8            0.832692           0.871992           0.877767
# 9            0.838462           0.881617           0.875842
# 10           0.835577           0.877767           0.878730
# 11           0.848077           0.879692           0.890279
# 12           0.801923           0.809432           0.823869
# 13           0.839423           0.853705           0.863330
# 14           0.834615           0.880654           0.879692
# 15           0.839423           0.854668           0.863330
# 16           0.753846           0.754572           0.753609
# 17           0.835577           0.879692           0.882579
# 18           0.840385           0.877767           0.885467
# 19           0.839423           0.871030           0.878730
# 20           0.834615           0.878730           0.878730
# 21           0.767308           0.754572           0.753609
# 22           0.843269           0.880654           0.884504
# 23           0.834615           0.877767           0.882579
# 24           0.831731           0.870067           0.873917
# 25           0.844231           0.884504           0.887392
# 26           0.833654           0.871992           0.875842
# 27           0.847115           0.882579           0.887392
# 28           0.840385           0.854668           0.863330
# 29           0.837500           0.880654           0.875842
# 30           0.767308           0.754572           0.753609
# 31           0.840385           0.854668           0.862368
# 32           0.837500           0.876805           0.884504
# 33           0.833654           0.860443           0.874880
# 34           0.835577           0.861405           0.874880
# 35           0.819231           0.811357           0.832531
# 36           0.845192           0.877767           0.884504
# 37           0.836538           0.860443           0.875842
# 38           0.845192           0.882579           0.887392
# 39           0.838462           0.876805           0.881617
# 40           0.753846           0.754572           0.753609
# 41           0.843269           0.875842           0.883542
# 42           0.842308           0.874880           0.886429
# 43           0.834615           0.867180           0.877767
# 44           0.838462           0.878730           0.886429
# 45           0.838462           0.875842           0.886429
# 46           0.753846           0.754572           0.753609
# 47           0.835577           0.873917           0.879692
# 48           0.844231           0.878730           0.887392
# 49           0.836538           0.879692           0.884504
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.867180         0.866659        0.015024               20
# 1            0.827719         0.822784        0.005948               42
# 2            0.863330         0.865312        0.015994               24
# 3            0.824832         0.812973        0.009939               44
# 4            0.862368         0.864927        0.016446               27
# 5            0.861405         0.864927        0.016779               25
# 6            0.869105         0.867429        0.016740               16
# 7            0.871992         0.867429        0.018300               15
# 8            0.857555         0.860501        0.015596               31
# 9            0.863330         0.865504        0.014901               23
# 10           0.863330         0.863388        0.015614               28
# 11           0.878730         0.877625        0.015665                1
# 12           0.822907         0.811626        0.010112               45
# 13           0.846968         0.846262        0.012097               41
# 14           0.861405         0.864927        0.016779               25
# 15           0.847931         0.846840        0.011943               39
# 16           0.753609         0.753896        0.000354               48
# 17           0.869105         0.867429        0.016763               16
# 18           0.872955         0.870122        0.015502               11
# 19           0.873917         0.866851        0.013995               19
# 20           0.863330         0.863004        0.016199               29
# 21           0.753609         0.756589        0.005371               46
# 22           0.878730         0.872816        0.014986                6
# 23           0.867180         0.867044        0.016996               18
# 24           0.860443         0.858578        0.014798               33
# 25           0.876805         0.874932        0.015743                4
# 26           0.857555         0.860501        0.014870               32
# 27           0.878730         0.875894        0.014652                2
# 28           0.847931         0.847032        0.011829               38
# 29           0.863330         0.865888        0.015286               22
# 30           0.753609         0.756589        0.005371               46
# 31           0.847931         0.846647        0.011869               40
# 32           0.868142         0.867621        0.016059               14
# 33           0.855630         0.855883        0.013244               37
# 34           0.855630         0.855883        0.012802               36
# 35           0.827719         0.821245        0.007816               43
# 36           0.871992         0.870314        0.013372               10
# 37           0.856593         0.856845        0.012573               35
# 38           0.876805         0.875317        0.015458                3
# 39           0.867180         0.866659        0.015024               20
# 40           0.753609         0.753896        0.000354               48
# 41           0.872955         0.870506        0.014053                9
# 42           0.873917         0.869738        0.014676               13
# 43           0.849856         0.857614        0.014750               34
# 44           0.873917         0.871854        0.017185                7
# 45           0.874880         0.871469        0.017026                8
# 46           0.753609         0.753896        0.000354               48
# 47           0.860443         0.862618        0.015204               30
# 48           0.875842         0.873393        0.015068                5
# 49           0.871992         0.869738        0.017106               12

# %%
searchCV.best_params_
# Out:
# {'min_samples_leaf': 5, 'max_depth': 15, 'criterion': 'entropy'}

# %%
searchCV.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=15, min_samples_leaf=5,
#                        n_estimators=300, random_state=7)
