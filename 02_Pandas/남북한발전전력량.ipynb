# %%
# 모듈 준비
import pandas as pd

# %%
# 데이터 준비 - 엑셀
data_file=r'C:\Users\KDP-27\Desktop\EX_PANDAS06\남북한발전전력량.xlsx'

# %%
#%pip install openpyxl

# %%
# xlsx 파일 ==> DataFrame으로 저장
xlsxDF=pd.read_excel(data_file)

# %%
xlsxDF
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
xlsxDF.iloc[1:5,0]='남한'

# %%
xlsxDF
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1        남한     수력    64    51    49    60    41    55    52    54  ...    50
# 2        남한     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3        남한    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4        남한    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
xlsxDF.iloc[6:,0]='북한'

# %%
xlsxDF
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1        남한     수력    64    51    49    60    41    55    52    54  ...    50
# 2        남한     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3        남한    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4        남한    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6        북한     수력   156   150   142   133   138   142   125   107  ...   133
# 7        북한     화력   121   113   105    88    93    88    88    86  ...   103
# 8        북한    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
xlsxDF.loc[10]='북한'

# %%
xlsxDF
# Out:
#    전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  \
# 0         남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...
# 1         남한     수력    64    51    49    60    41    55    52    54  ...
# 2         남한     화력   484   573   696   803  1022  1122  1264  1420  ...
# 3         남한    원자력   529   563   565   581   587   670   739   771  ...
# 4         남한    신재생     -     -     -     -     -     -     -     -  ...
# 5         북한     합계   277   263   247   221   231   230   213   193  ...
# 6         북한     수력   156   150   142   133   138   142   125   107  ...
# 7         북한     화력   121   113   105    88    93    88    88    86  ...
# 8         북한    원자력     -     -     -     -     -     -     -     -  ...
# 10        북한     북한    북한    북한    북한    북한    북한    북한    북한    북한  ...
#
#     2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0   4031  4224  4336  4747  4969  5096  5171  5220  5281  5404
# ...

# %%
xlsxDF.iloc[9,1]='신재생'
xlsxDF
# Out:
#    전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  \
# 0         남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...
# 1         남한     수력    64    51    49    60    41    55    52    54  ...
# 2         남한     화력   484   573   696   803  1022  1122  1264  1420  ...
# 3         남한    원자력   529   563   565   581   587   670   739   771  ...
# 4         남한    신재생     -     -     -     -     -     -     -     -  ...
# 5         북한     합계   277   263   247   221   231   230   213   193  ...
# 6         북한     수력   156   150   142   133   138   142   125   107  ...
# 7         북한     화력   121   113   105    88    93    88    88    86  ...
# 8         북한    원자력     -     -     -     -     -     -     -     -  ...
# 10        북한    신재생    북한    북한    북한    북한    북한    북한    북한    북한  ...
#
#     2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0   4031  4224  4336  4747  4969  5096  5171  5220  5281  5404
# ...

# %%
xlsxDF.iloc[9,2:]=0
xlsxDF
# Out:
#    전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  \
# 0         남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...
# 1         남한     수력    64    51    49    60    41    55    52    54  ...
# 2         남한     화력   484   573   696   803  1022  1122  1264  1420  ...
# 3         남한    원자력   529   563   565   581   587   670   739   771  ...
# 4         남한    신재생     -     -     -     -     -     -     -     -  ...
# 5         북한     합계   277   263   247   221   231   230   213   193  ...
# 6         북한     수력   156   150   142   133   138   142   125   107  ...
# 7         북한     화력   121   113   105    88    93    88    88    86  ...
# 8         북한    원자력     -     -     -     -     -     -     -     -  ...
# 10        북한    신재생     0     0     0     0     0     0     0     0  ...
#
#     2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0   4031  4224  4336  4747  4969  5096  5171  5220  5281  5404
# ...

# %%
xlsxDF.iloc[8,2:]=0
xlsxDF
# Out:
#    전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  \
# 0         남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...
# 1         남한     수력    64    51    49    60    41    55    52    54  ...
# 2         남한     화력   484   573   696   803  1022  1122  1264  1420  ...
# 3         남한    원자력   529   563   565   581   587   670   739   771  ...
# 4         남한    신재생     -     -     -     -     -     -     -     -  ...
# 5         북한     합계   277   263   247   221   231   230   213   193  ...
# 6         북한     수력   156   150   142   133   138   142   125   107  ...
# 7         북한     화력   121   113   105    88    93    88    88    86  ...
# 8         북한    원자력     0     0     0     0     0     0     0     0  ...
# 10        북한    신재생     0     0     0     0     0     0     0     0  ...
#
#     2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0   4031  4224  4336  4747  4969  5096  5171  5220  5281  5404
# ...

# %%
xlsxDF.iloc[4,2:-5]=0
xlsxDF
# Out:
#    전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  \
# 0         남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...
# 1         남한     수력    64    51    49    60    41    55    52    54  ...
# 2         남한     화력   484   573   696   803  1022  1122  1264  1420  ...
# 3         남한    원자력   529   563   565   581   587   670   739   771  ...
# 4         남한    신재생     0     0     0     0     0     0     0     0  ...
# 5         북한     합계   277   263   247   221   231   230   213   193  ...
# 6         북한     수력   156   150   142   133   138   142   125   107  ...
# 7         북한     화력   121   113   105    88    93    88    88    86  ...
# 8         북한    원자력     0     0     0     0     0     0     0     0  ...
# 10        북한    신재생     0     0     0     0     0     0     0     0  ...
#
#     2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0   4031  4224  4336  4747  4969  5096  5171  5220  5281  5404
# ...

# %%
xlsxDF['합계']=0

# %%
xlsxDF
# Out:
#    전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  \
# 0         남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...
# 1         남한     수력    64    51    49    60    41    55    52    54  ...
# 2         남한     화력   484   573   696   803  1022  1122  1264  1420  ...
# 3         남한    원자력   529   563   565   581   587   670   739   771  ...
# 4         남한    신재생     0     0     0     0     0     0     0     0  ...
# 5         북한     합계   277   263   247   221   231   230   213   193  ...
# 6         북한     수력   156   150   142   133   138   142   125   107  ...
# 7         북한     화력   121   113   105    88    93    88    88    86  ...
# 8         북한    원자력     0     0     0     0     0     0     0     0  ...
# 10        북한    신재생     0     0     0     0     0     0     0     0  ...
#
#     2008  2009  2010  2011  2012  2013  2014  2015  2016 합계
# 0   4224  4336  4747  4969  5096  5171  5220  5281  5404  0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 xlsxDF['1990':'2016']
#
# File c:\Users\KDP-27\anaconda3\envs\PY39\lib\site-packages\pandas\core\frame.py:4085, in DataFrame.__getitem__(self, key)
#    4083 # Do we have a slicer (on rows)?
#    4084 if isinstance(key, slice):
# -> 4085     return self._getitem_slice(key)
#    4087 # Do we have a (boolean) DataFrame?
#    4088 if isinstance(key, DataFrame):
#
# File c:\Users\KDP-27\anaconda3\envs\PY39\lib\site-packages\pandas\core\generic.py:4349, in NDFrame._getitem_slice(self, key)
#    4344 """
#    4345 __getitem__ for the case where the key is a slice object.
#    4346 """
#    4347 # _convert_slice_indexer to determine if this slice is positional
#    4348 #  or label based, and if the latter, convert to positional
# -> 4349 slobj = self.index._convert_slice_indexer(key, kind="getitem")
# ...
